# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.tree import DecisionTreeRegressor 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
col_names = ['Age', 'Number_of_sexual_partners','First sexual intercourse','Num of pregnancies','Smokes', 'Smokes (years)','Smokes (packs/year)', 'Hormonal Contraceptives','Hormonal Contraceptives (years)','IUD','IUD (years)','STDs','STDs (number)','STDs:condylomatosis', 'STDs:cervical condylomatosis','STDs:vaginal condylomatosis','STDs:vulvo-perineal condylomatosis','STDs:syphilis','STDs:pelvic inflammatory disease','STDs:genital herpes','STDs:molluscum contagiosum','STDs:AIDS','STDs:HIV','STDs:Hepatitis B','STDs:HPV','STDs: Number of diagnosis','Dx:Cancer','Dx:CIN','Dx:HPV','Dx','Hinselmann','Schiller','Citology','Biopsy']
# load dataset
pima = pd.read_csv("/content/drive/MyDrive/data3.csv", header=0, names=col_names)
pima.head()
# Out:
#    Age  Number_of_sexual_partners  ...  Citology  Biopsy
# 0   18                          4  ...         0       0
# 1   15                          1  ...         0       0
# 2   52                          5  ...         0       0
# 3   46                          3  ...         0       0
# 4   42                          3  ...         0       0
#
# [5 rows x 34 columns]

# %%
#split dataset in features and target variable
feature_cols = ['Age','Number_of_sexual_partners','First sexual intercourse','Num of pregnancies','Smokes', 'Smokes (years)','Smokes (packs/year)', 'Hormonal Contraceptives','Hormonal Contraceptives (years)','IUD','IUD (years)','STDs','STDs (number)','STDs:condylomatosis', 'STDs:cervical condylomatosis','STDs:vaginal condylomatosis','STDs:vulvo-perineal condylomatosis','STDs:syphilis','STDs:pelvic inflammatory disease','STDs:genital herpes','STDs:molluscum contagiosum','STDs:AIDS','STDs:HIV','STDs:Hepatitis B','STDs:HPV','STDs: Number of diagnosis','Dx:Cancer','Dx:CIN','Dx:HPV','Dx','Hinselmann','Schiller','Citology','Biopsy']
X = pima[feature_cols] # Features
y = pima.Age # Target variable

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
print (X_test,X_train)
# Out:
#      Age  Number_of_sexual_partners  ...  Citology  Biopsy
# 507   27                          6  ...         0       0
# 563   34                          3  ...         0       0
# 23    39                          2  ...         0       0
# 555   31                          3  ...         0       0
# 90    30                          4  ...         0       0
# ..   ...                        ...  ...       ...     ...
# 259   17                          2  ...         0       0
# 406   28                          3  ...         0       0
# 139   29                          4  ...         0       0
# 157   27                          2  ...         0       0
# 16    43                          2  ...         0       0
#
# [177 rows x 34 columns]      Age  Number_of_sexual_partners  ...  Citology  Biopsy
# 564   35                          4  ...         0       0
# 459   17                          4  ...         0       0
# ...

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9717514124293786

# %%
sns.lmplot(data=pima, x="Age", y="First sexual intercourse", hue="Age", fit_reg=False, height=6, aspect=1.5)

# %%
plt.hist(pima, density=True)  # density=False would make counts
plt.ylabel('Probability')
plt.xlabel('Data');

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import tree

# %%
clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_0 <= 21.50
# |   |--- feature_0 <= 20.50
# |   |   |--- feature_0 <= 19.50
# |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- class: 13
# |   |   |   |   |   |   |   |   |--- feature_2 >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: 14
# |   |   |   |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |   |   |   |--- class: 15
# |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |--- class: 16
# |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |--- class: 17
# |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |--- class: 18
# |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |--- class: 19
# ...

# %%
with open("decistion_tree.log", "w") as fout:
    fout.write(text_representation)

# %%
fig = plt.figure(figsize=(255,252))
_ = tree.plot_tree(clf)

# %%
fig.savefig("decision_tree.png")

# %%
sns.displot(pima, x="Age", hue="Dx:Cancer", kind="kde", fill=True)
sns.displot(pima, x="Dx:Cancer", hue="Age", kind="kde", fill=True)
sns.displot(pima, x="Age", hue="Number_of_sexual_partners", kind="kde", fill=True)
sns.displot(pima, x="Age", hue="Num of pregnancies", kind="kde", fill=True)
sns.displot(pima, x="Number_of_sexual_partners", hue="Dx:Cancer", kind="kde", fill=True)
sns.displot(pima, x="Age", hue="STDs", kind="kde", fill=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
# ...

# %%
cor = pima.corr()
sns.heatmap(cor)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# create a regressor object
regressor = DecisionTreeRegressor(random_state = 0) 
  
# fit the regressor with X and Y data
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=0, splitter='best')

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.07909604519774012
# Mean Squared Error: 0.4971751412429379
# Root Mean Squared Error: 0.7051064751106303
